# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
tf.__version__
# Out:
# '2.21.0'

# %%
# Import Dataset
mnistDataset = tf.keras.datasets.mnist

# Split the dataset
(x_train, y_train), (x_test, y_test) = mnistDataset.load_data()

plt.imshow(x_train[0])
plt.plot()
# x_train[0]

# Normalize (0-1)
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
# Model Architecture
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer="adam", 
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# W0000 00:00:1775570792.729848    8735 cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9230 - loss: 0.2647
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9662 - loss: 0.1073
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9772 - loss: 0.0734

# %%
#Evaluate Model
val_loss, val_acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9717 - loss: 0.0887

# %%
# Predict
predictions = model.predict(x_test)

plt.figure()
plt.imshow(x_test[2])
print("PREDICTION: ", np.argmax(predictions[2]))
plt.show()

plt.figure()
plt.imshow(x_test[4])
print("PREDICTION: ", np.argmax(predictions[4]))
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step
# PREDICTION:  1
# PREDICTION:  4
